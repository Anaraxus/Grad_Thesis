# %% [markdown]
# ## Convolutional Neural Network for Student University Selection Prediction

# %% [markdown]
# ### Install tensorflow GPU

# %%
# !pip install tensorflow-gpu==2.0.0-rc0
# Out:
# ...
#      |████████████████████████████████| 380.5MB 41kB/s
# ...
#      |████████████████████████████████| 501kB 38.1MB/s
# ...
#      |████████████████████████████████| 4.3MB 30.2MB/s
# ...
#      |████████████████████████████████| 51kB 3.2MB/s
# ...

# %% [markdown]
# ### Import Tensorflow Dependencies

# %%
import tensorflow as tf
from tensorflow.keras import Sequential

from tensorflow.keras.layers import Conv1D, MaxPool1D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
print(tf.__version__)
# Out:
# 2.0.0-rc0

# %% [markdown]
# ### Import Python Dipendencies

# %%
import numpy as np      # Python Math libs
import pandas as pd     # Python Data libs 
import seaborn as sns   # Python Random Distributions Visualization Libs
import matplotlib.pyplot as plt

# %% [markdown]
# ### Use sklearn ML Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# ### Mount Drive

# %%
# Mount drive to access csv files in colab folder
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Get Data

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/InstitutionFinancialData2012_Train_New - InstitutionFinancialData2012_Train_NL.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-6539c98a6e83> in <module>()
# ----> 1 data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/InstitutionFinancialData2012_Train_New - InstitutionFinancialData2012_Train_NL.csv')
#       2 data.head()
#
# ...

# %%
data.shape
# Out:
# (4299, 99)

# %%
# Drop Slect Columns
X = data.drop(labels=['Choice'], axis = 1)
X.shape
# Out:
# (4299, 98)

# %%
Y = data['Choice']

# %%
X_train, X_test, y_train, y_test=train_test_split(X,Y,test_size= 0.2,random_state=0,stratify=Y)

# %%
X_train.shape, X_test.shape
# Out:
# ((3439, 98), (860, 98))

# %% [markdown]
# #### Feature Selection:

# %%
 # Remove any features with varaince less than 1
filter = VarianceThreshold(0.01) 
X_train = filter.fit_transform(X_train)
X_test = filter.transform(X_test)

X_train.shape, X_test.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-01032e72260a> in <module>()
#       1 # Remove any features with varaince less than 1
#       2 filter = VarianceThreshold(0.5)
# ----> 3 X_train = filter.fit_transform(X_train)
#       4 X_test = filter.transform(X_test)
#       5
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/_variance_threshold.py in fit(self, X, y)
#      67         """
#      68         X = check_array(X, ('csr', 'csc'), dtype=np.float64,
# ...
